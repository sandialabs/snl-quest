# %% [markdown]
# # btm_flow_2026_new runner
#
# Run the first code cell below to execute the generated Python flow script using `%run`.

# %%
script_path = r"C:\work\quest210\snl-quest\btm_flow_2026_new_program.py"
print(f"Running: {script_path}")
# %run "$script_path"
