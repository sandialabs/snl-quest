# %% [markdown]
# # Master_btm_flow_2026 runner
#
# Run the first code cell below to execute the generated Python flow script using `%run`.

# %%
script_path = r"c:\work\quest21\snl-quest\master_btm_flow_2026_program.py"
print(f"Running: {script_path}")
# %run "$script_path"
# Out:
# Running: c:\work\quest21\snl-quest\master_btm_flow_2026_program.py
# pv_path_outputs: {'pv_path': 'C:/work/quest20c/quest2/ZeroPV1.json'}
# rate_path_outputs: {'rate_path': 'C:/work/quest20c/quest2/Dominion1MWtou.json'}
# power rating_outputs: {'power': 100}
# rte_outputs: {'rte': 0.88}
# energy capacity_outputs: {'energy': 400}
# load_path_outputs: {'load_path': 'C:/work/quest20c/quest2/data_center_virginia_10MW.csv'}
# Running with: C:/work/quest20c/quest2/Lib/site-packages/quest/app_envs/env_btm/Scripts/python.exe
# Output:
#
# Error:
#  Traceback (most recent call last):
#   File "C:\Users\tunguy\AppData\Local\Temp\tmprynmet_0\btm_flow_2026_program.py", line 22, in <module>
#     from btm.es_gui.apps.btm.op_handler_workspace import BtmOptimizerHandler
#   File "C:\work\quest20c\quest2\Lib\site-packages\quest\app_envs\env_btm\lib\site-packages\btm\es_gui\apps\btm\op_handler_workspace.py", line 11, in <module>
#     from btm.es_gui.tools.btm.btm_optimizer import BtmOptimizer, BadParameterException, IncompatibleDataException
#   File "C:\work\quest20c\quest2\Lib\site-packages\quest\app_envs\env_btm\lib\site-packages\btm\es_gui\tools\btm\btm_optimizer.py", line 5, in <module>
#     from pyomo.environ import *
# ModuleNotFoundError: No module named 'pyomo'
#
# An error occurred while running the script: Traceback (most recent call last):
#   File "C:\Users\tunguy\AppData\Local\Temp\tmprynmet_0\btm_flow_2026_program.py", line 22, in <module>
#     from btm.es_gui.apps.btm.op_handler_workspace import BtmOptimizerHandler
#   File "C:\work\quest20c\quest2\Lib\site-packages\quest\app_envs\env_btm\lib\site-packages\btm\es_gui\apps\btm\op_handler_workspace.py", line 11, in <module>
#     from btm.es_gui.tools.btm.btm_optimizer import BtmOptimizer, BadParameterException, IncompatibleDataException
#   File "C:\work\quest20c\quest2\Lib\site-packages\quest\app_envs\env_btm\lib\site-packages\btm\es_gui\tools\btm\btm_optimizer.py", line 5, in <module>
#     from pyomo.environ import *
# ModuleNotFoundError: No module named 'pyomo'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File C:\work\quest21\snl-quest\master_btm_flow_2026_program.py:115
#     113 print('energy capacity_outputs:',node0x16ce2ce0070.get_outputs())
#     114 print('load_path_outputs:',node0x16ce2ce03d0.get_outputs())
# --> 115 print('btm_flow_2026_outputs:',node0x16ce2ce0670.get_outputs())
#
# File C:\work\quest21\snl-quest\quest\snl_libraries\workspace\nodes\pynodes.py:45, in python_node.get_outputs(self)
#      42 if (not self._dirty) and (self._last_input_snapshot == snapshot):
#      43     return self.output_values
# ---> 45 result = self.function(**self.input_values)
#      47 if isinstance(result, dict):
#      48     self.output_values = result
#
# File C:\work\quest21\snl-quest\master_btm_flow_2026_program.py:80, in btm_flow_2026_function(pv_path, rate_path, power_rating, energy_capacity, rte, load_path)
#      78 subflow_connections_df = pd.DataFrame([{'connection_id': 1, 'from_node': '0x1e5266dd910', 'to_node': '0x1e5266dda90', 'mapping': {'data_path': 'data_path'}}, {'connection_id': 2, 'from_node': '0x1e5266dda90', 'to_node': '0x1e52672d7c0', 'mapping': {'dms': 'dms'}}, {'connection_id': 3, 'from_node': '0x1e52674e790', 'to_node': '0x1e5266ddd60', 'mapping': {'load_path': 'load_data_path'}}, {'connection_id': 4, 'from_node': '0x1e5266ddd60', 'to_node': '0x1e52672d5e0', 'mapping': {'load_profile': 'load_profile'}}, {'connection_id': 5, 'from_node': '0x1e5266ddeb0', 'to_node': '0x1e52672d100', 'mapping': {'pv_path': 'pv_data_path'}}, {'connection_id': 6, 'from_node': '0x1e52672d100', 'to_node': '0x1e52672d5e0', 'mapping': {'pv_profile': 'pv_profile'}}, {'connection_id': 7, 'from_node': '0x1e52672d250', 'to_node': '0x1e52672d460', 'mapping': {'rate_path': 'rate_path'}}, {'connection_id': 8, 'from_node': '0x1e52672d460', 'to_node': '0x1e52672d5e0', 'mapping': {'rate_structure': 'rate_structure'}}, {'connection_id': 9, 'from_node': '0x1e52672df10', 'to_node': '0x1e52672d5e0', 'mapping': {'ess_parameters': 'ess_parameters'}}, {'connection_id': 10, 'from_node': '0x1e52672d5e0', 'to_node': '0x1e52672d7c0', 'mapping': {'btm_op_request': 'btm_op_request'}}, {'connection_id': 11, 'from_node': '0x1e52674e5e0', 'to_node': '0x1e52672d7c0', 'mapping': {'solver_name': 'solver_name'}}, {'connection_id': 12, 'from_node': '0x1e52672d7c0', 'to_node': '0x1e52674e940', 'mapping': {'btm_solved_ops': 'solved_ops'}}, {'connection_id': 13, 'from_node': '0x1e52672db50', 'to_node': '0x1e52672df10', 'mapping': {'power': 'power'}}, {'connection_id': 14, 'from_node': '0x1e52674e0d0', 'to_node': '0x1e52672df10', 'mapping': {'energy': 'energy'}}, {'connection_id': 15, 'from_node': '0x1e52674e430', 'to_node': '0x1e52672df10', 'mapping': {'rte': 'rte'}}, {'connection_id': 16, 'from_node': '0x1e52674eac0', 'to_node': '0x1e52674e940', 'mapping': {'rs_location': 'saved_location'}}])
#      79 subflow_nodes_df = update_subflow(subflow_nodes_df, pv_path=pv_path, rate_path=rate_path, power_rating=power_rating, energy_capacity=energy_capacity, rte=rte, load_path=load_path)
# ---> 80 _results = run_subflow(subflow_name, subflow_nodes_df, subflow_connections_df, python_executable='C:/work/quest20c/quest2/Lib/site-packages/quest/app_envs/env_btm/Scripts/python.exe')
#      81 return {'saved_location': _results.get('results', {}).get('saved_location'), 'checkpoints': _results.get('results', {}).get('checkpoints')}
#
# File C:\work\quest21\snl-quest\master_btm_flow_2026_program.py:66, in btm_flow_2026_function.<locals>.run_subflow(subflow_name, subflow_nodes_df, subflow_connections_df, python_executable)
#      64 with tempfile.TemporaryDirectory() as tmpdir:
#      65     f.save(tmpdir + os.sep)
# ---> 66     result = f.run(python_executable=python_executable)
#      67     stdout = getattr(result, 'stdout', '') or ''
#      68 start_marker = '__QUEST_SUBFLOW_RESULTS_START__'
#
# File C:\work\quest21\snl-quest\quest\snl_libraries\workspace\flow\questflow.py:418, in flow.run(self, python_executable, stream_output)
#     415         print("Error:\n", result.stderr)
#     417     if result.returncode != 0:
# --> 418         raise RuntimeError(result.stderr or "Flow execution failed")
#     420     return result
#     422 except Exception as e:
#
# RuntimeError: Traceback (most recent call last):
#   File "C:\Users\tunguy\AppData\Local\Temp\tmprynmet_0\btm_flow_2026_program.py", line 22, in <module>
#     from btm.es_gui.apps.btm.op_handler_workspace import BtmOptimizerHandler
#   File "C:\work\quest20c\quest2\Lib\site-packages\quest\app_envs\env_btm\lib\site-packages\btm\es_gui\apps\btm\op_handler_workspace.py", line 11, in <module>
#     from btm.es_gui.tools.btm.btm_optimizer import BtmOptimizer, BadParameterException, IncompatibleDataException
#   File "C:\work\quest20c\quest2\Lib\site-packages\quest\app_envs\env_btm\lib\site-packages\btm\es_gui\tools\btm\btm_optimizer.py", line 5, in <module>
#     from pyomo.environ import *
# ModuleNotFoundError: No module named 'pyomo'
